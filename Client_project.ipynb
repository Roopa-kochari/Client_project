# %% [markdown]
# # Connecting Python to MySQL database

# %%
pip install mysql.connector
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sqlalchemy import create_engine
from urllib.parse import quote_plus

password = quote_plus("DM!$!Team!27@9!20&")

engine = create_engine(
    f"mysql+mysqlconnector://dm_team3:{password}@18.136.157.135/project_telecom"
)

query = "SELECT * FROM telecom_churn_data LIMIT 20"
df = pd.read_sql(query, engine)
print(df)
# Out:
#    columns1 columns2 columns3   columns4 columns5 columns6 columns7 columns8  \
# 0        KS      128      415   382-4657       no      yes       25    265.1
# 1        OH      107      415   371-7191       no      yes       26    161.6
# 2        NJ      137      415   358-1921       no       no        0    243.4
# 3        OH       84      408   375-9999      yes       no        0    299.4
# 4        OK       75      415   330-6626      yes       no        0    166.7
# 5        AL      118      510   391-8027      yes       no        0    223.4
# 6        MA      121      510   355-9993       no      yes       24    218.2
# 7        MO      147      415   329-9001      yes       no        0      157
# 8        LA      117      408   335-4719       no       no        0    184.5
# 9        WV      141      415   330-8173      yes      yes       37    258.6
# 10       IN       65      415   329-6603       no       no        0    129.1
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df
# Out:
#    columns1 columns2 columns3   columns4 columns5 columns6 columns7 columns8  \
# 0        KS      128      415   382-4657       no      yes       25    265.1
# 1        OH      107      415   371-7191       no      yes       26    161.6
# 2        NJ      137      415   358-1921       no       no        0    243.4
# 3        OH       84      408   375-9999      yes       no        0    299.4
# 4        OK       75      415   330-6626      yes       no        0    166.7
# 5        AL      118      510   391-8027      yes       no        0    223.4
# 6        MA      121      510   355-9993       no      yes       24    218.2
# 7        MO      147      415   329-9001      yes       no        0      157
# 8        LA      117      408   335-4719       no       no        0    184.5
# 9        WV      141      415   330-8173      yes      yes       37    258.6
# 10       IN       65      415   329-6603       no       no        0    129.1
# ...

# %% [markdown]
# # Basic checks

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 21 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   columns1   20 non-null     object
#  1   columns2   20 non-null     object
#  2   columns3   20 non-null     object
#  3   columns4   20 non-null     object
#  4   columns5   20 non-null     object
#  5   columns6   20 non-null     object
#  6   columns7   20 non-null     object
#  7   columns8   20 non-null     object
#  8   columns9   20 non-null     object
#  9   columns10  20 non-null     object
#  10  columns11  20 non-null     object
#  11  columns12  20 non-null     object
#  12  columns13  20 non-null     object
#  13  columns14  20 non-null     object
#  14  columns15  20 non-null     object
#  15  columns16  20 non-null     object
#  16  columns17  20 non-null     object
#  17  columns18  20 non-null     object
#  18  columns19  20 non-null     object
# ...

# %%
df.size
# Out:
# 420

# %%
df.shape
# Out:
# (20, 21)

# %% [markdown]
#  Coverting the column name's

# %%
df.rename(columns={'columns1':'State','columns2':'Account Length','columns3': 'Area Code','columns4': 'Phone','columns5': 'International Plan','columns6': 'VMail Plan',
    'columns7': 'VMail Message','columns8': 'Day Mins','columns9': 'Day Calls','columns10': 'Day Charge','columns11': 'Eve Mins','columns12': 'Eve Calls',
    'columns13': 'Eve Charge','columns14': 'Night Mins','columns15': 'Night Calls','columns16': 'Night Charge','columns17': 'International Mins','columns18': 'International calls',
    'columns19': 'International Charge',
    'columns20': 'CustServ Calls',
    'columns21': 'Churn'
}, inplace=True)

# %%
df
# Out:
#    State Account Length Area Code      Phone International Plan VMail Plan  \
# 0     KS            128       415   382-4657                 no        yes
# 1     OH            107       415   371-7191                 no        yes
# 2     NJ            137       415   358-1921                 no         no
# 3     OH             84       408   375-9999                yes         no
# 4     OK             75       415   330-6626                yes         no
# 5     AL            118       510   391-8027                yes         no
# 6     MA            121       510   355-9993                 no        yes
# 7     MO            147       415   329-9001                yes         no
# 8     LA            117       408   335-4719                 no         no
# 9     WV            141       415   330-8173                yes        yes
# 10    IN             65       415   329-6603                 no         no
# ...

# %%
df.columns
# Out:
# Index(['State', 'Account Length', 'Area Code', 'Phone', 'International Plan',
#        'VMail Plan', 'VMail Message', 'Day Mins', 'Day Calls', 'Day Charge',
#        'Eve Mins', 'Eve Calls', 'Eve Charge', 'Night Mins', 'Night Calls',
#        'Night Charge', 'International Mins', 'International calls',
#        'International Charge', 'CustServ Calls', 'Churn'],
#       dtype='object')

# %% [markdown]
# #Converting the object-dtype to int-dtype

# %%
#Converting the object-dtype to int-dtype 
cols = ['Account Length', 'Area Code', 'VMail Message', 'Day Mins', 'Day Calls', 'Day Charge', 'Eve Mins', 'Eve Charge','Eve Calls','Night Mins', 'Night Calls', 'Night Charge', 'International Mins', 'International calls', 'International Charge', 'CustServ Calls']
df[cols] = df[cols].astype(float).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   State                 20 non-null     object
#  1   Account Length        20 non-null     int32
#  2   Area Code             20 non-null     int32
#  3   Phone                 20 non-null     object
#  4   International Plan    20 non-null     object
#  5   VMail Plan            20 non-null     object
#  6   VMail Message         20 non-null     int32
#  7   Day Mins              20 non-null     int32
#  8   Day Calls             20 non-null     int32
#  9   Day Charge            20 non-null     int32
#  10  Eve Mins              20 non-null     int32
#  11  Eve Calls             20 non-null     int32
#  12  Eve Charge            20 non-null     int32
#  13  Night Mins            20 non-null     int32
#  14  Night Calls           20 non-null     int32
# ...

# %%
#df['Phone'] = df['Phone'].str.replace('-', '').astype(int)
#df['Phone']=df['Phone'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   State                 20 non-null     object
#  1   Account Length        20 non-null     int32
#  2   Area Code             20 non-null     int32
#  3   Phone                 20 non-null     object
#  4   International Plan    20 non-null     object
#  5   VMail Plan            20 non-null     object
#  6   VMail Message         20 non-null     int32
#  7   Day Mins              20 non-null     int32
#  8   Day Calls             20 non-null     int32
#  9   Day Charge            20 non-null     int32
#  10  Eve Mins              20 non-null     int32
#  11  Eve Calls             20 non-null     int32
#  12  Eve Charge            20 non-null     int32
#  13  Night Mins            20 non-null     int32
#  14  Night Calls           20 non-null     int32
# ...

# %%
#drop column
df.drop(['State','Phone'],axis=1,inplace=True)

# %%
df
# Out:
#     Account Length  Area Code International Plan VMail Plan  VMail Message  \
# 0              128        415                 no        yes             25
# 1              107        415                 no        yes             26
# 2              137        415                 no         no              0
# 3               84        408                yes         no              0
# 4               75        415                yes         no              0
# 5              118        510                yes         no              0
# 6              121        510                 no        yes             24
# 7              147        415                yes         no              0
# 8              117        408                 no         no              0
# 9              141        415                yes        yes             37
# 10              65        415                 no         no              0
# ...

# %% [markdown]
# ### Applying LableEncoder

# %%
#apply label encoder to convert into int dtype
cols=['International Plan','VMail Plan','Churn']
from sklearn.preprocessing import LabelEncoder
encode=LabelEncoder()
for col in cols:
    df[col]=encode.fit_transform(df[col])

# %%
df
# Out:
#     Account Length  Area Code  International Plan  VMail Plan  VMail Message  \
# 0              128        415                   0           1             25
# 1              107        415                   0           1             26
# 2              137        415                   0           0              0
# 3               84        408                   1           0              0
# 4               75        415                   1           0              0
# 5              118        510                   1           0              0
# 6              121        510                   0           1             24
# 7              147        415                   1           0              0
# 8              117        408                   0           0              0
# 9              141        415                   1           1             37
# 10              65        415                   0           0              0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Account Length        20 non-null     int32
#  1   Area Code             20 non-null     int32
#  2   International Plan    20 non-null     int32
#  3   VMail Plan            20 non-null     int32
#  4   VMail Message         20 non-null     int32
#  5   Day Mins              20 non-null     int32
#  6   Day Calls             20 non-null     int32
#  7   Day Charge            20 non-null     int32
#  8   Eve Mins              20 non-null     int32
#  9   Eve Calls             20 non-null     int32
#  10  Eve Charge            20 non-null     int32
#  11  Night Mins            20 non-null     int32
#  12  Night Calls           20 non-null     int32
#  13  Night Charge          20 non-null     int32
#  14  International Mins    20 non-null     int32
# ...

# %%
#check null values
df.isnull().sum()
# Out:
# Account Length          0
# Area Code               0
# International Plan      0
# VMail Plan              0
# VMail Message           0
# Day Mins                0
# Day Calls               0
# Day Charge              0
# Eve Mins                0
# Eve Calls               0
# Eve Charge              0
# Night Mins              0
# Night Calls             0
# Night Charge            0
# International Mins      0
# International calls     0
# International Charge    0
# CustServ Calls          0
# Churn                   0
# dtype: int64

# %%
#check Duplicate's
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # EDA

# %%
#plot boxplot to identify outliers
plt.figure(figsize=(10,10))
plot = 1

for i in df:
    if plot<=9:
        ax = plt.subplot(3,3,plot)
        sns.boxplot(x=df[i])
        plt.xlabel(i)
    plot+=1
plt.tight_layout()

# %%
plt.show()

# %%
#Histplot
plt.figure(figsize=(12, 8))
plot = 1

for i in df.columns[:9]:  
    ax = plt.subplot(3, 3, plot)
    sns.histplot(x=df[i], ax=ax)  
    ax.set_xlabel(i)
    plot += 1
plt.tight_layout()

plt.show()

# %%
#scatterplot
sns.scatterplot(df)
plt.show()

# %%
#heatmap for understanding co-relation
sns.heatmap(df.drop(['Churn'],axis=1).corr())
plt.show()

# %% [markdown]
# # Model Bulding

# %%
# init X
X=df.drop('Churn',axis=1)
#init y
y=df[['Churn']]

# %%
from sklearn.model_selection import train_test_split
# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
# Create scaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
# Create model
model = LogisticRegression(max_iter=1000)
# Train model
model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
# predication test data
y_pred=model.predict(X_test_scaled)

# %%
y_pred
# Out:
# array([0, 0, 0, 0, 0, 0])

# %%
#model accuracy score
model.score(X_test, y_test)
# Out:
# 0.8333333333333334

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, f1_score, recall_score,classification_report

# %%
LR_accuracy_score=accuracy_score(y_test,y_pred)
LR_accuracy_score
# Out:
# 0.8333333333333334

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[5, 0],
#        [1, 0]], dtype=int64)

# %%
train_acc = model.score(X_train, y_train)
test_acc = model.score(X_test, y_test)

print(f"Training Accuracy: {train_acc:.2f}")
print(f"Testing Accuracy: {test_acc:.2f}")
# Out:
# Training Accuracy: 1.00
# Testing Accuracy: 0.83

# %%
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91         5
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.83         6
#    macro avg       0.42      0.50      0.45         6
# weighted avg       0.69      0.83      0.76         6

# %%
LR_result= pd.DataFrame({ LR_accuracy_score,'LogisticRegression'}).transpose()
LR_result.columns=['LR_accuracy_score','Model']
LR_result
# Out:
#   LR_accuracy_score               Model
# 0          0.833333  LogisticRegression

# %% [markdown]
# #  XGBClassifier
# ## 2nd model

# %%
#init model
from xgboost import XGBClassifier
xgb_model = XGBClassifier(
    n_estimators=200,
    learning_rate=0.05,
    max_depth=5,
    random_state=42,
    use_label_encoder=False,
    eval_metric='logloss'
)
#fit the model
xgb_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
#predict the model per
y_predi = xgb_model.predict(X_test)

# %%
y_predi
# Out:
# array([0, 0, 0, 0, 0, 0])

# %%
XG_Accuracy=accuracy_score(y_test, y_predi)
XG_Accuracy
# Out:
# 0.8333333333333334

# %%
print("XG_Accuracy:", accuracy_score(y_test, y_predi))
print("Confusion Matrix:", confusion_matrix(y_test, y_predi))
print("\nClassification Report:\n", classification_report(y_test, y_predi))
# Out:
# XG_Accuracy: 0.8333333333333334
# Confusion Matrix: [[5 0]
#  [1 0]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91         5
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.83         6
#    macro avg       0.42      0.50      0.45         6
# weighted avg       0.69      0.83      0.76         6

# %%
#accuracy score
train_acc = xgb_model.score(X_train, y_train)
test_acc = xgb_model.score(X_test, y_test)

print(f"Training Accuracy: {train_acc:.2f}")
print(f"Testing Accuracy: {test_acc:.2f}")
# Out:
# Training Accuracy: 0.93
# Testing Accuracy: 0.83

# %%
XG_result= pd.DataFrame({ XG_Accuracy,'XGBClassifier'}).transpose()
XG_result.columns=['XG_accuracy_score','Model']
XG_result
# Out:
#   XG_accuracy_score          Model
# 0          0.833333  XGBClassifier

# %% [markdown]
# # RandomForestRegressor
# #3rd

# %%
#create model
from sklearn.ensemble import RandomForestRegressor
RF_model = RandomForestRegressor(n_estimators=200, random_state=42)
#fit model
RF_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=200, random_state=42)

# %%
RF_model.score(X_test, y_test)
# Out:
# 0.05704000000000009

# %%
y_predic=RF_model.predict(X_test)
y_predic
# Out:
# array([0.025, 0.005, 0.115, 0.03 , 0.025, 0.02 ])

# %%
RF_model= pd.DataFrame({ RF_model.score(X_test, y_test),'RandomForestRegressor'}).transpose()
RF_model.columns=['RF_model_accuracy_score','Model']
RF_model
# Out:
#   RF_model_accuracy_score                  Model
# 0                 0.05704  RandomForestRegressor

# %% [markdown]
# ## Models_comparison

# %%
Models_comparison= pd.concat([LR_result,XG_result,RF_model],axis=1)
Models_comparison
# Out:
#   LR_accuracy_score               Model XG_accuracy_score          Model  \
# 0          0.833333  LogisticRegression          0.833333  XGBClassifier
#
#   RF_model_accuracy_score                  Model
# 0                 0.05704  RandomForestRegressor
